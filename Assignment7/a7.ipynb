# %% [markdown]
# <a href="https://colab.research.google.com/github/sojo06/TE-SPPU-LAB-SEM-6/blob/DSBDL/Assignment7/a7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DSBDAL Assignment 7

# %% [markdown]
# ### Import Required Libraries

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Download NLTK Resources

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger")
nltk.download("punkt_tab")
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %% [markdown]
# ### Sample Document Input

# %%
doc = """
Education plays a very important role in shaping the future of individuals and society.
It helps people gain knowledge, develop skills, and build confidence. From childhood,
students learn basic subjects like mathematics, science, language, and history, which
form the foundation for higher studies.

In today’s world, education is not limited to classrooms only. Online learning platforms,
digital libraries, and interactive courses have made knowledge accessible to everyone.
Many students also participate in extracurricular activities such as sports, music,
debates, and cultural events to improve their overall personality.

Teachers guide learners by providing support, motivation, and discipline. At the same time,
parents contribute by encouraging good habits and creating a positive learning environment
at home. Education also helps in developing moral values such as honesty, responsibility,
and respect for others.

A well-educated person can contribute to the progress of the nation by working in various
fields like medicine, engineering, business, arts, and public service. Therefore, education
is considered one of the most powerful tools for personal growth and national development.
"""

print("Sample Document:\n", doc)
# Out:
# Sample Document:
#
# Education plays a very important role in shaping the future of individuals and society.
# It helps people gain knowledge, develop skills, and build confidence. From childhood,
# students learn basic subjects like mathematics, science, language, and history, which
# form the foundation for higher studies.
#
# In today’s world, education is not limited to classrooms only. Online learning platforms,
# digital libraries, and interactive courses have made knowledge accessible to everyone.
# Many students also participate in extracurricular activities such as sports, music,
# debates, and cultural events to improve their overall personality.
#
# Teachers guide learners by providing support, motivation, and discipline. At the same time,
# parents contribute by encouraging good habits and creating a positive learning environment
# at home. Education also helps in developing moral values such as honesty, responsibility,
# and respect for others.
#
# ...

# %% [markdown]
# ## Document Preprocessing Methods

# %% [markdown]
# ### Tokenization

# %%
tokens = word_tokenize(doc)
print("Tokens:\n", tokens)
# Out:
# Tokens:
# ...

# %% [markdown]
# ### POS Tagging

# %%
pos_tags = nltk.pos_tag(tokens)
print("POS Tags:\n", pos_tags)
# Out:
# POS Tags:
# ...

# %% [markdown]
# ### Stop Words Removal

# %%
stop_words = set(stopwords.words("english"))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word not in string.punctuation]
print("After Stop Word Removal:\n", filtered_tokens)
# Out:
# After Stop Word Removal:
# ...

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
for w, s in zip(filtered_tokens, stemmed_words):
    print(w, ":", s)
# Out:
# Education : educ
# plays : play
# important : import
# role : role
# shaping : shape
# future : futur
# individuals : individu
# society : societi
# helps : help
# people : peopl
# gain : gain
# knowledge : knowledg
# develop : develop
# skills : skill
# build : build
# confidence : confid
# childhood : childhood
# students : student
# learn : learn
# basic : basic
# subjects : subject
# like : like
# mathematics : mathemat
# science : scienc
# language : languag
# history : histori
# form : form
# foundation : foundat
# higher : higher
# studies : studi
# today : today
# ’ : ’
# world : world
# education : educ
# limited : limit
# classrooms : classroom
# Online : onlin
# learning : learn
# platforms : platform
# digital : digit
# libraries : librari
# interactive : interact
# courses : cours
# made : made
# knowledge : knowledg
# accessible : access
# everyone : everyon
# Many : mani
# students : student
# also : also
# participate : particip
# extracurricular : extracurricular
# ...

# %% [markdown]
# ### Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
for w, s in zip(filtered_tokens, lemmatized_words):
    print(w, ":", s)
# Out:
# Education : Education
# plays : play
# important : important
# role : role
# shaping : shaping
# future : future
# individuals : individual
# society : society
# helps : help
# people : people
# gain : gain
# knowledge : knowledge
# develop : develop
# skills : skill
# build : build
# confidence : confidence
# childhood : childhood
# students : student
# learn : learn
# basic : basic
# subjects : subject
# like : like
# mathematics : mathematics
# science : science
# language : language
# history : history
# form : form
# foundation : foundation
# higher : higher
# studies : study
# today : today
# ’ : ’
# world : world
# education : education
# limited : limited
# classrooms : classroom
# Online : Online
# learning : learning
# platforms : platform
# digital : digital
# libraries : library
# interactive : interactive
# courses : course
# made : made
# knowledge : knowledge
# accessible : accessible
# everyone : everyone
# Many : Many
# students : student
# also : also
# ...

# %% [markdown]
# ## TF and IDF Representation

# %% [markdown]
# ### Term Frequency (TF)

# %%
from collections import Counter

tf = Counter(filtered_tokens)

print("Term Frequency:\n")
for word, freq in tf.items():
    print(word, ":", freq)
# Out:
# Term Frequency:
#
# Education : 2
# plays : 1
# important : 1
# role : 1
# shaping : 1
# future : 1
# individuals : 1
# society : 1
# helps : 2
# people : 1
# gain : 1
# knowledge : 2
# develop : 1
# skills : 1
# build : 1
# confidence : 1
# childhood : 1
# students : 2
# learn : 1
# basic : 1
# subjects : 1
# like : 2
# mathematics : 1
# science : 1
# language : 1
# history : 1
# form : 1
# foundation : 1
# higher : 1
# studies : 1
# today : 1
# ’ : 1
# world : 1
# education : 2
# limited : 1
# classrooms : 1
# Online : 1
# learning : 2
# platforms : 1
# digital : 1
# libraries : 1
# interactive : 1
# courses : 1
# made : 1
# accessible : 1
# everyone : 1
# Many : 1
# also : 2
# participate : 1
# extracurricular : 1
# activities : 1
# sports : 1
# music : 1
# debates : 1
# cultural : 1
# events : 1
# improve : 1
# overall : 1
# personality : 1
# Teachers : 1
# guide : 1
# learners : 1
# providing : 1
# support : 1
# motivation : 1
# discipline : 1
# time : 1
# parents : 1
# ...

# %% [markdown]
# ### TF-IDF Representation

# %%
documents = [doc]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print("TF-IDF Feature Names:\n", vectorizer.get_feature_names_out())
print("\nTF-IDF Values:\n", tfidf_matrix.toarray())
# Out:
# TF-IDF Feature Names:
#  ['accessible' 'activities' 'also' 'and' 'arts' 'as' 'at' 'basic' 'build'
#  'business' 'by' 'can' 'childhood' 'classrooms' 'confidence' 'considered'
#  'contribute' 'courses' 'creating' 'cultural' 'debates' 'develop'
#  'developing' 'development' 'digital' 'discipline' 'educated' 'education'
#  'encouraging' 'engineering' 'environment' 'events' 'everyone'
#  'extracurricular' 'fields' 'for' 'form' 'foundation' 'from' 'future'
#  'gain' 'good' 'growth' 'guide' 'habits' 'have' 'helps' 'higher' 'history'
#  'home' 'honesty' 'important' 'improve' 'in' 'individuals' 'interactive'
#  'is' 'it' 'knowledge' 'language' 'learn' 'learners' 'learning'
#  'libraries' 'like' 'limited' 'made' 'many' 'mathematics' 'medicine'
#  'moral' 'most' 'motivation' 'music' 'nation' 'national' 'not' 'of' 'one'
#  'online' 'only' 'others' 'overall' 'parents' 'participate' 'people'
#  'person' 'personal' 'personality' 'platforms' 'plays' 'positive'
# ...
